# %%
import jieba

# %%
jieba.load_userdict("library_new_words.txt")
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 1.484 seconds.
# Prefix dict has been built successfully.

# %%
import pandas

# %%
datas=pandas.read_excel("图书目录.xlsx")

# %%
datas["书名"]=datas["书名"].str.strip()

# %%
datas["图书分类号"]=datas["图书分类号"].str.strip()

# %%
datas[datas["书名"].notnull()]
# Out:
#             图书ID            书名            图书分类号
# 0       B0000001          大庆指南  F279.273.5-62/1
# 1       B0000002  寒夜三部曲.第一部,寒夜         I247.5/1
# 2       B0000003           沧桑路       I247.5/184
# 3       B0000004             寻         I247.5/4
# 4       B0000005         曾经深爱过         I247.5/5
# ...          ...           ...              ...
# 400961  B0507925      凰权:第一卷.上   I247.57/5445:1
# 400962  B0507926      凰权:第一卷.中   I247.57/5445:1
# 400963  B0507927      凰权:第一卷.下   I247.57/5445:1
# 400964  B0507928          傅雷家书       K825.6/789
# 400965  B0507929    摆渡人.2,重返荒原    I561.45/751:2
#
# [400694 rows x 3 columns]

# %%
datas=datas[datas["书名"].notnull() &  datas["图书分类号"].notnull()]

# %%
datas=datas[["书名","图书分类号"]]

# %%
datas
# Out:
#                   书名            图书分类号
# 0               大庆指南  F279.273.5-62/1
# 1       寒夜三部曲.第一部,寒夜         I247.5/1
# 2                沧桑路       I247.5/184
# 3                  寻         I247.5/4
# 4              曾经深爱过         I247.5/5
# ...              ...              ...
# 400961      凰权:第一卷.上   I247.57/5445:1
# 400962      凰权:第一卷.中   I247.57/5445:1
# 400963      凰权:第一卷.下   I247.57/5445:1
# 400964          傅雷家书       K825.6/789
# 400965    摆渡人.2,重返荒原    I561.45/751:2
#
# [393068 rows x 2 columns]

# %%
datas.drop_duplicates()
# Out:
#                   书名            图书分类号
# 0               大庆指南  F279.273.5-62/1
# 1       寒夜三部曲.第一部,寒夜         I247.5/1
# 2                沧桑路       I247.5/184
# 3                  寻         I247.5/4
# 4              曾经深爱过         I247.5/5
# ...              ...              ...
# 400961      凰权:第一卷.上   I247.57/5445:1
# 400962      凰权:第一卷.中   I247.57/5445:1
# 400963      凰权:第一卷.下   I247.57/5445:1
# 400964          傅雷家书       K825.6/789
# 400965    摆渡人.2,重返荒原    I561.45/751:2
#
# [349930 rows x 2 columns]

# %%
datas=datas.drop_duplicates()

# %%
datas
# Out:
#                   书名            图书分类号
# 0               大庆指南  F279.273.5-62/1
# 1       寒夜三部曲.第一部,寒夜         I247.5/1
# 2                沧桑路       I247.5/184
# 3                  寻         I247.5/4
# 4              曾经深爱过         I247.5/5
# ...              ...              ...
# 400961      凰权:第一卷.上   I247.57/5445:1
# 400962      凰权:第一卷.中   I247.57/5445:1
# 400963      凰权:第一卷.下   I247.57/5445:1
# 400964          傅雷家书       K825.6/789
# 400965    摆渡人.2,重返荒原    I561.45/751:2
#
# [349930 rows x 2 columns]

# %%
datas=datas.reindex()

# %%
datas
# Out:
#                   书名            图书分类号
# 0               大庆指南  F279.273.5-62/1
# 1       寒夜三部曲.第一部,寒夜         I247.5/1
# 2                沧桑路       I247.5/184
# 3                  寻         I247.5/4
# 4              曾经深爱过         I247.5/5
# ...              ...              ...
# 400961      凰权:第一卷.上   I247.57/5445:1
# 400962      凰权:第一卷.中   I247.57/5445:1
# 400963      凰权:第一卷.下   I247.57/5445:1
# 400964          傅雷家书       K825.6/789
# 400965    摆渡人.2,重返荒原    I561.45/751:2
#
# [349930 rows x 2 columns]

# %%
aaaa=pandas.DataFrame(jieba.analyse.extract_tags(x) for x in datas["书名"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-f3f5710e448f> in <module>
# ----> 1 aaaa=pandas.DataFrame(jieba.analyse.extract_tags(x) for x in datas["书名"])
#
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     443         elif isinstance(data, abc.Iterable) and not isinstance(data, (str, bytes)):
#     444             if not isinstance(data, abc.Sequence):
# --> 445                 data = list(data)
#     446             if len(data) > 0:
#     447                 if is_list_like(data[0]) and getattr(data[0], "ndim", 1) == 1:
#
# <ipython-input-32-f3f5710e448f> in <genexpr>(.0)
# ----> 1 aaaa=pandas.DataFrame(jieba.analyse.extract_tags(x) for x in datas["书名"])
#
# AttributeError: module 'jieba' has no attribute 'analyse'
